# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("./fft_test.txt", delimiter='\t')

# %%
print(df)
# Out:
#          Freq          Mag    Mag(dB)
# 0         0.0     1.000000   0.000000
# 1        86.2     1.000000   0.000000
# 2       172.3     1.000000   0.000000
# 3       258.5     1.000000   0.000000
# 4       344.7     1.000000   0.000000
# 5       430.8     1.000000   0.000000
# 6       517.0     1.000000   0.000000
# 7       603.2     1.000000   0.000000
# 8       689.3     1.000000   0.000000
# 9       775.5     1.000000   0.000000
# 10      861.7     1.000000   0.000000
# 11      947.8     1.000000   0.000000
# 12     1034.0   213.602173  23.296055
# 13     1120.2   215.703262  23.338568
# 14     1206.3   349.622284  25.435991
# 15     1292.5   258.025757  24.116631
# 16     1378.7   115.957123  20.642975
# 17     1464.8   148.638245  21.721306
# 18     1551.0   137.944031  21.397028
# 19     1637.2   103.265488  20.139551
# 20     1723.3   120.285088  20.802118
# 21     1809.5   222.532867  23.473942
# 22     1895.7    29.231365  14.658491
# 23     1981.8   177.140869  22.483187
# ...

# %%
df.plot(x='Freq', y='Mag(dB)')
