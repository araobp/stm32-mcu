# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("./freq15000.txt", delimiter='\t')

# %%
print(df)
# Out:
#          Freq          Mag    Mag(dB)
# 0         0.0     1.000000   0.000000
# 1        86.2     1.000000   0.000000
# 2       172.3     1.000000   0.000000
# 3       258.5     1.000000   0.000000
# 4       344.7     1.000000   0.000000
# 5       430.8     1.000000   0.000000
# 6       517.0     1.000000   0.000000
# 7       603.2     1.000000   0.000000
# 8       689.3     1.000000   0.000000
# 9       775.5     1.000000   0.000000
# 10      861.7     1.000000   0.000000
# 11      947.8     1.000000   0.000000
# 12     1034.0   124.899445  20.965605
# 13     1120.2   280.227905  24.475115
# 14     1206.3   370.660980  25.689770
# 15     1292.5   219.223984  23.408880
# 16     1378.7   218.945938  23.403368
# 17     1464.8   148.744904  21.724422
# 18     1551.0   125.024918  20.969965
# 19     1637.2   222.650070  23.476229
# 20     1723.3   132.697311  21.228621
# 21     1809.5    45.584892  16.588209
# 22     1895.7    86.568550  19.373602
# 23     1981.8   142.384048  21.534615
# ...

# %%
df.plot(x='Freq', y='Mag(dB)')
